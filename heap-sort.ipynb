# %% [markdown]
# # Heap sort
# ***

# %% [markdown]
# ## Introduction
#
# ***
#
# I will discuss a <b><i>Heap Sort algorithm</i></b> within this jupyter notebook. I will explain this with the following headings:
# - An explination of the Heap Sort Alogorithm
# - Python function implementing Heap Sort
# - Explaination of the computational complexity of Heap Sort
# - Explaination of how graph theory is used in Heap Sort.

# %% [markdown]
# ## Explaination
#
# ***
#
# Using the elements given in an array, heap sort processed the elements by creating a min-heap or max-heap. According to <i>javatpoint.com</i>, min-heap and max-heap represents the ordering of an array in which the root element represents the minimum or maximum element of the arry.
#
# Heap Sort undertakes two main operations in a recurring loop.
# - Build a heap using the elements of an array.
# - Repeatedly deleting the root element of the heap.
#
# Before we discuss heap sort any more, we must first understand the description of <b>Heap</b>

# %% [markdown]
# ### What is a heap
#
# A <b>Heap</b> is a specific tree based structure called an ordered binary tree. A heapis always a complete binary tree, meaning that every level or the tree, except possibly the deepest level, is completely filled. Each node can have at most 2 children.
#
# ![CompleteBinary.jpg](attachment:CompleteBinary.jpg)

# %% [markdown]
# ### What is a heap sort
#
# Heapsort is a popular and efficient sorting algorithm used to arrange a list of elements in order. It uses the tree concept, Heap Tree. This is when a list of elements are sorted in descending order called <b>max heap</b> or <b>min heap</b>, when a list of elements are sorted in ascending order.

# %% [markdown]
# ### Difference between Max and Min Heap
#
# The difference between Min-Heap or Max-Heap is determined based on if the parent nodes are either greater than of less than the children nodes. If the parent node is greater than the child node, the heap is called a Max-Heap. The first element in the tree is the largest, hence why the list of elements are sorted in a descending order. If the parent nodes are smaller than their childrens nodes are called Min-Heap. This is used when we want to sort lists in ascending order. The first element is always the smallest.

# %% [markdown]
# #### Max Heap
#
# In a Max Heap the key present at the root node must be greater than or equal to among the keys present at all of its children. The maximun key element must be present at the root of the tree and use a descending priority. In the construction of a max heap, the largest element has priority.
#
# ![MaxHeap.jpg](attachment:MaxHeap.jpg)

# %% [markdown]
# #### Min Heap
#
# In a Min Heap the key presents at the root node must be less than or equal to among the key presents at all of its children. The minimum key element must be present at the root of the three and use an ascending order. In the contruction of a min heap, the smallest element has priority.
#
# ![minHeap.png](attachment:minHeap.png)
